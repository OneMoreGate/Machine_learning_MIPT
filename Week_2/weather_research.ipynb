# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %%
df = pd.read_csv('tambov.csv', sep=';', comment='#', index_col=False, low_memory=False)
df.rename(columns={f'{df.columns[0]}' : 'Time'}, inplace=True)
df.head()
# Out:
#                Time    T     Po      P   Pa     U  \
# 0  31.12.2022 21:00  1.1  752.6  764.7  1.3  96.0
# 1  31.12.2022 18:00  1.4  751.3  763.3  1.8  89.0
# 2  31.12.2022 15:00  1.4  749.5  761.5 -0.2  94.0
# 3  31.12.2022 12:00  1.7  749.7  761.6  0.2  93.0
# 4  31.12.2022 09:00  1.2  749.5  761.5 -0.3  96.0
#
#                                      DD   Ff  ff10  ff3  ...  \
# 0  Ветер, дующий с западо-северо-запада  6.0   NaN  NaN  ...
# 1                Ветер, дующий с запада  6.0   NaN  NaN  ...
# 2     Ветер, дующий с западо-юго-запада  5.0   NaN  NaN  ...
# 3     Ветер, дующий с западо-юго-запада  4.0   NaN  NaN  ...
# 4            Ветер, дующий с юго-запада  5.0   NaN  NaN  ...
#
#                                                   Cm   Ch    VV   Td  RRR  \
# 0                                                NaN  NaN  10.0  0.5  NaN
# 1                                                NaN  NaN  10.0 -0.2  3.0
# 2  Высокослоистые непросвечивающие или слоисто-до...  NaN  10.0  0.5  NaN
# 3                                                NaN  NaN  10.0  0.6  NaN
# 4  Высокослоистые непросвечивающие или слоисто-до...  NaN   7.0  0.6  NaN
#
#      tR    E  Tg   E'  sss
# 0   NaN  NaN NaN  NaN  NaN
# 1  12.0  NaN NaN  NaN  NaN
# 2   NaN  NaN NaN  NaN  NaN
# 3   NaN  NaN NaN  NaN  NaN
# 4   NaN  NaN NaN  NaN  NaN
#
# [5 rows x 29 columns]

# %%
df.isnull().sum()
# Out:
# Time        0
# T          99
# Po        136
# P         122
# Pa      20548
# U         150
# DD        970
# Ff        965
# ff10    46809
# ff3     44063
# N          13
# WW          0
# W1      33987
# W2      33987
# Tn      42323
# Tx      43268
# Cl      10271
# Nh       6491
# H        6414
# Cm      18900
# Ch      23944
# VV         21
# Td         59
# RRR     39223
# tR      39223
# E       43747
# Tg      48961
# E'      47154
# sss     47544
# dtype: int64

# %%
df['Time'] = pd.Series([dt.datetime.strptime(i, '%d.%m.%Y %H:%M').date() for i in df['Time']])

# %%
sub_Time_U = pd.DataFrame({'Date': df['Time'], 'Humidity' : df['U']}).dropna()
sub_Time_T = pd.DataFrame({'Date': df['Time'], 'Temperature' : df['T']}).dropna()

# %%
plt.plot(sub_Time_U['Date'], sub_Time_U['Humidity'], linewidth = 0.1)

# %%
plt.plot(sub_Time_T['Date'], sub_Time_T['Temperature'], linewidth = 0.1)

# %%
sub = df.loc[:,['T', 'Po']][df['DD'] == df['DD'].unique()[2]].dropna()
sub_2 = df.loc[:,['T', 'Po']][df['DD'] == df['DD'].unique()[9]].dropna()
plt.scatter(sub['Po'], sub['T'], s=1)
plt.scatter(sub_2['Po'], sub_2['T'], s=1)
plt.title(df['DD'].unique()[2]+ ' ' + df['DD'].unique()[9])
# Out:
# Text(0.5, 1.0, 'Ветер, дующий с западо-юго-запада Ветер, дующий с востоко-северо-востока')

# %%
pd.pivot_table(df,
    values='T',
    index= 'DD',
    columns='Cm',
    aggfunc=np.mean
)
# Out:
# Cm                                      Высококучевые башенкообразные или хлопьевидные.  \
# DD
# Ветер, дующий с востока                                                       -0.446154
# Ветер, дующий с востоко-северо-востока                                         3.158537
# Ветер, дующий с востоко-юго-востока                                            0.677647
# Ветер, дующий с запада                                                         2.331159
# Ветер, дующий с западо-северо-запада                                           2.717814
# Ветер, дующий с западо-юго-запада                                              3.450303
# Ветер, дующий с севера                                                         4.049721
# Ветер, дующий с северо-востока                                                 4.177885
# Ветер, дующий с северо-запада                                                  3.656716
# Ветер, дующий с северо-северо-востока                                          4.500000
# Ветер, дующий с северо-северо-запада                                           3.190566
# Ветер, дующий с юга                                                            2.657396
# Ветер, дующий с юго-востока                                                    0.309184
# Ветер, дующий с юго-запада                                                     2.381433
# Ветер, дующий с юго-юго-востока                                                1.325000
# Ветер, дующий с юго-юго-запада                                                 1.444413
# Переменное направление                                                              NaN
# Штиль, безветрие                                                               1.309524
#
# Cm                                      Высококучевые просвечивающие, полосами, либо один или несколько слоев высококучевых просвечивающих, распространяющихся по небу; эти высококучевые в целом уплотняются.  \
# DD
# Ветер, дующий с востока                                                         10.384615
# Ветер, дующий с востоко-северо-востока                                          13.600000
# Ветер, дующий с востоко-юго-востока                                              0.811111
# Ветер, дующий с запада                                                           4.613333
# Ветер, дующий с западо-северо-запада                                             4.037500
# Ветер, дующий с западо-юго-запада                                                7.080000
# Ветер, дующий с севера                                                           7.016667
# Ветер, дующий с северо-востока                                                  20.750000
# Ветер, дующий с северо-запада                                                    5.614286
# Ветер, дующий с северо-северо-востока                                            9.766667
# Ветер, дующий с северо-северо-запада                                             1.600000
# Ветер, дующий с юга                                                              7.252000
# Ветер, дующий с юго-востока                                                      7.718182
# Ветер, дующий с юго-запада                                                       1.635714
# Ветер, дующий с юго-юго-востока                                                  2.870588
# Ветер, дующий с юго-юго-запада                                                   9.856250
# Переменное направление                                                          18.500000
# Штиль, безветрие                                                                 7.971429
#
# Cm                                      Высококучевые просвечивающие, расположенные на одном уровне.  \
# DD
# Ветер, дующий с востока                                                         14.513732
# Ветер, дующий с востоко-северо-востока                                          13.910903
# Ветер, дующий с востоко-юго-востока                                             11.771593
# Ветер, дующий с запада                                                           8.875189
# Ветер, дующий с западо-северо-запада                                             8.533556
# Ветер, дующий с западо-юго-запада                                                9.649286
# Ветер, дующий с севера                                                          12.284606
# Ветер, дующий с северо-востока                                                  13.998525
# Ветер, дующий с северо-запада                                                    8.401373
# Ветер, дующий с северо-северо-востока                                           14.442105
# Ветер, дующий с северо-северо-запада                                             9.080411
# Ветер, дующий с юга                                                              9.768015
# Ветер, дующий с юго-востока                                                      9.988920
# Ветер, дующий с юго-запада                                                      10.982039
# Ветер, дующий с юго-юго-востока                                                 11.135763
# Ветер, дующий с юго-юго-запада                                                   9.447834
# Переменное направление                                                          13.305352
# Штиль, безветрие                                                                 9.314047
#
# Cm                                      Высококучевые, образовавшиеся из кучевых (или кучево-дождевых).  \
# DD
# Ветер, дующий с востока                                                          0.400000
# Ветер, дующий с востоко-северо-востока                                                NaN
# Ветер, дующий с востоко-юго-востока                                             11.925000
# Ветер, дующий с запада                                                          -0.720000
# Ветер, дующий с западо-северо-запада                                             1.733333
# Ветер, дующий с западо-юго-запада                                               10.566667
# Ветер, дующий с севера                                                          12.300000
# Ветер, дующий с северо-востока                                                        NaN
# Ветер, дующий с северо-запада                                                   22.200000
# Ветер, дующий с северо-северо-востока                                                 NaN
# Ветер, дующий с северо-северо-запада                                             5.833333
# Ветер, дующий с юга                                                              7.500000
# Ветер, дующий с юго-востока                                                      6.600000
# Ветер, дующий с юго-запада                                                      17.900000
# Ветер, дующий с юго-юго-востока                                                  7.587500
# Ветер, дующий с юго-юго-запада                                                   4.400000
# Переменное направление                                                          19.800000
# Штиль, безветрие                                                                 6.255556
#
# Cm                                      Высококучевые, просвечивающие или плотные в двух или более слоях или высококучевые плотные в одном слое, не распространяющиеся но небу, либо высококучевые с высокослоистыми или слоисто-дождевыми.  \
# DD
# Ветер, дующий с востока                                                         11.660870
# Ветер, дующий с востоко-северо-востока                                          18.350000
# Ветер, дующий с востоко-юго-востока                                              9.100000
# Ветер, дующий с запада                                                           9.176923
# Ветер, дующий с западо-северо-запада                                            13.670000
# Ветер, дующий с западо-юго-запада                                                8.752941
# Ветер, дующий с севера                                                           9.957895
# Ветер, дующий с северо-востока                                                  19.400000
# Ветер, дующий с северо-запада                                                    8.177778
# Ветер, дующий с северо-северо-востока                                           15.240000
# Ветер, дующий с северо-северо-запада                                            12.257143
# Ветер, дующий с юга                                                              3.796552
# Ветер, дующий с юго-востока                                                      9.383721
# Ветер, дующий с юго-запада                                                       9.342857
# Ветер, дующий с юго-юго-востока                                                  7.903030
# Ветер, дующий с юго-юго-запада                                                  10.968421
# Переменное направление                                                          14.861905
# Штиль, безветрие                                                                 9.668421
#
# Cm                                      Высококучевых, высокослоистых или слоисто-дождевых облаков нет.  \
# DD
# Ветер, дующий с востока                                                         15.180535
# Ветер, дующий с востоко-северо-востока                                          17.744444
# Ветер, дующий с востоко-юго-востока                                             10.826367
# Ветер, дующий с запада                                                          11.539976
# Ветер, дующий с западо-северо-запада                                            11.421997
# Ветер, дующий с западо-юго-запада                                               11.692688
# Ветер, дующий с севера                                                          15.192109
# Ветер, дующий с северо-востока                                                  15.560317
# Ветер, дующий с северо-запада                                                   11.031839
# Ветер, дующий с северо-северо-востока                                           15.856828
# Ветер, дующий с северо-северо-запада                                            13.744417
# Ветер, дующий с юга                                                             11.468167
# Ветер, дующий с юго-востока                                                     10.093428
# Ветер, дующий с юго-запада                                                      12.419693
# Ветер, дующий с юго-юго-востока                                                 11.066667
# Ветер, дующий с юго-юго-запада                                                  13.562873
# Переменное направление                                                          16.231579
# Штиль, безветрие                                                                 7.039579
#
# Cm                                      Высокослоистые непросвечивающие или слоисто-дождевые.  \
# DD
# Ветер, дующий с востока                                                         -3.129677
# Ветер, дующий с востоко-северо-востока                                          -3.315714
# Ветер, дующий с востоко-юго-востока                                             -4.028141
# Ветер, дующий с запада                                                          -3.834579
# Ветер, дующий с западо-северо-запада                                            -3.268750
# Ветер, дующий с западо-юго-запада                                               -1.307207
# Ветер, дующий с севера                                                          -3.281879
# Ветер, дующий с северо-востока                                                  -4.194915
# Ветер, дующий с северо-запада                                                   -2.729167
# Ветер, дующий с северо-северо-востока                                           -1.310169
# Ветер, дующий с северо-северо-запада                                            -3.281818
# Ветер, дующий с юга                                                             -1.243175
# Ветер, дующий с юго-востока                                                     -2.938342
# Ветер, дующий с юго-запада                                                      -1.249645
# Ветер, дующий с юго-юго-востока                                                 -1.731412
# Ветер, дующий с юго-юго-запада                                                  -1.835583
# Переменное направление                                                          -1.620000
# Штиль, безветрие                                                                -5.475342
#
# Cm                                      Высокослоистые просвечивающие.  \
# DD
# Ветер, дующий с востока                                      -6.412821
# Ветер, дующий с востоко-северо-востока                       -7.675000
# Ветер, дующий с востоко-юго-востока                          -4.872340
# Ветер, дующий с запада                                       -1.542857
# Ветер, дующий с западо-северо-запада                         -9.325532
# Ветер, дующий с западо-юго-запада                            -2.190000
# Ветер, дующий с севера                                       -4.794340
# Ветер, дующий с северо-востока                               -5.516216
# Ветер, дующий с северо-запада                                -6.959524
# Ветер, дующий с северо-северо-востока                        -8.262500
# Ветер, дующий с северо-северо-запада                         -5.623944
# Ветер, дующий с юга                                          -3.439552
# Ветер, дующий с юго-востока                                  -4.692771
# Ветер, дующий с юго-запада                                   -1.971111
# Ветер, дующий с юго-юго-востока                              -3.227500
# Ветер, дующий с юго-юго-запада                               -1.347727
# Переменное направление                                       10.900000
# Штиль, безветрие                                             -6.843564
#
# Cm                                      Клочья (часто чечевицеобразные) высококучевых просвечивающих, непрерывно изменяющихся; расположены на одном или более уровнях.
# DD
# Ветер, дующий с востока                                                               NaN
# Ветер, дующий с востоко-северо-востока                                                NaN
# Ветер, дующий с востоко-юго-востока                                                   NaN
# Ветер, дующий с запада                                                                NaN
# Ветер, дующий с западо-северо-запада                                                  NaN
# Ветер, дующий с западо-юго-запада                                                   -5.05
# Ветер, дующий с севера                                                               2.60
# Ветер, дующий с северо-востока                                                        NaN
# Ветер, дующий с северо-запада                                                         NaN
# Ветер, дующий с северо-северо-востока                                                 NaN
# Ветер, дующий с северо-северо-запада                                                  NaN
# Ветер, дующий с юга                                                                   NaN
# Ветер, дующий с юго-востока                                                           NaN
# Ветер, дующий с юго-запада                                                            NaN
# Ветер, дующий с юго-юго-востока                                                       NaN
# Ветер, дующий с юго-юго-запада                                                        NaN
# Переменное направление                                                                NaN
# Штиль, безветрие                                                                      NaN

# %%
uniq_days = df['Time'].unique()
mean_d = np.array([df['T'][df['Time'] == i].dropna().mean() for i in uniq_days])
day_mean = pd.DataFrame({'Date': uniq_days, 'Temp': mean_d})

# %%
plt.plot(day_mean['Date'], day_mean['Temp'], linewidth = 0.4)

# %%
year = pd.Series([i.year for i in df['Time']])
month = pd.Series([i.month for i in df['Time']])
day = pd.Series([i.day for i in df['Time']])
temp = df['T']

qwerty = pd.DataFrame({'year': year, 'month': month, 'day': day, 'temp': temp}).dropna()

# %%
mean = np.array(pd.pivot_table(qwerty,
    values='temp',
    index= ['month', 'day'],
    aggfunc=np.mean
))
min = np.array(pd.pivot_table(qwerty,
    values='temp',
    index= ['month', 'day'],
    aggfunc=np.min
))
max = np.array(pd.pivot_table(qwerty,
    values='temp',
    index= ['month', 'day'],
    aggfunc=np.max
))

uniq_days_year = pd.Series([i for i in uniq_days if i.year == 2020 ]).unique()

plt.plot(uniq_days_year, mean[::-1])
plt.plot(uniq_days_year, min[::-1])
plt.plot(uniq_days_year, max[::-1])

# %%
mean = (pd.pivot_table(qwerty,
    values='temp',
    index= ['year','month', 'day'],
    aggfunc=np.mean
))
unique_days = df['Time'].unique()

plt.plot(unique_days, mean[::-1], linewidth = 0.4)
